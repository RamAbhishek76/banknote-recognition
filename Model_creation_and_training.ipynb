# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

X=pickle.load(open("X.pickle","rb"))
y=pickle.load(open("y.pickle","rb"))

X=X/255.0

dense_layers=[0]
layer_sizes=[64]
conv_layers=[3]


for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME="{}-conv-{}-nodes-{}-dense-{}".format(conv_layer,layer_size,dense_layer,int(time.time()))
            print(NAME)
            
            tensorboard=TensorBoard(log_dir='logs\{}'.format(NAME))

            model = Sequential()

            model.add(Conv2D(layer_size, (3,3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2,2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3,3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2,2)))

            model.add(Flatten())
            
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
                
            model.add(Dropout(0.1))    

            model.add(Dense(5))
            model.add(Activation('sigmoid'))

            model.compile(loss='sparse_categorical_crossentropy',
                         optimizer='adam',
                         metrics=['accuracy'])

            model.fit(X,y,batch_size=32,epochs=30,validation_split=0.2,callbacks=[tensorboard])
            
model.summary()            

model.save('0x64x3-CNN-30-epoch.model')
# Out:
# 3-conv-64-nodes-0-dense-1585581508
# Train on 1735 samples, validate on 434 samples
# Epoch 1/30
# 1735/1735 [==============================] - 73s 42ms/sample - loss: 1.5949 - acc: 0.2375 - val_loss: 1.4862 - val_acc: 0.3387
# Epoch 2/30
# 1735/1735 [==============================] - 61s 35ms/sample - loss: 1.3356 - acc: 0.4023 - val_loss: 1.3010 - val_acc: 0.4194
# Epoch 3/30
# 1735/1735 [==============================] - 66s 38ms/sample - loss: 1.1609 - acc: 0.5159 - val_loss: 1.4043 - val_acc: 0.4055
# Epoch 4/30
# 1735/1735 [==============================] - 61s 35ms/sample - loss: 1.0774 - acc: 0.5718 - val_loss: 1.1857 - val_acc: 0.4885
# Epoch 5/30
# 1735/1735 [==============================] - 69s 40ms/sample - loss: 0.9600 - acc: 0.6138 - val_loss: 1.1643 - val_acc: 0.5392
# Epoch 6/30
# 1735/1735 [==============================] - 61s 35ms/sample - loss: 0.8741 - acc: 0.6553 - val_loss: 0.9972 - val_acc: 0.6083
# Epoch 7/30
# 1735/1735 [==============================] - 61s 35ms/sample - loss: 0.7674 - acc: 0.6991 - val_loss: 1.0239 - val_acc: 0.6313
# Epoch 8/30
# 1735/1735 [==============================] - 73s 42ms/sample - loss: 0.7592 - acc: 0.6991 - val_loss: 1.0492 - val_acc: 0.6267
# Epoch 9/30
# 1735/1735 [==============================] - 72s 41ms/sample - loss: 0.6471 - acc: 0.7372 - val_loss: 1.0631 - val_acc: 0.6198
# Epoch 10/30
# 1735/1735 [==============================] - 92s 53ms/sample - loss: 0.6332 - acc: 0.7660 - val_loss: 1.0071 - val_acc: 0.6290
# Epoch 11/30
# 1735/1735 [==============================] - 74s 42ms/sample - loss: 0.5587 - acc: 0.7948 - val_loss: 1.0021 - val_acc: 0.6498
# Epoch 12/30
# 1735/1735 [==============================] - 75s 43ms/sample - loss: 0.4441 - acc: 0.8340 - val_loss: 1.0253 - val_acc: 0.6567
# Epoch 13/30
# 1735/1735 [==============================] - 67s 39ms/sample - loss: 0.4013 - acc: 0.8455 - val_loss: 1.1184 - val_acc: 0.6290
# Epoch 14/30
# 1735/1735 [==============================] - 65s 37ms/sample - loss: 0.3454 - acc: 0.8778 - val_loss: 1.2032 - val_acc: 0.6244
# Epoch 15/30
# 1735/1735 [==============================] - 64s 37ms/sample - loss: 0.3053 - acc: 0.8911 - val_loss: 1.0977 - val_acc: 0.6521
# Epoch 16/30
# 1735/1735 [==============================] - 59s 34ms/sample - loss: 0.2523 - acc: 0.9176 - val_loss: 1.1308 - val_acc: 0.6382
# Epoch 17/30
# 1735/1735 [==============================] - 69s 40ms/sample - loss: 0.2516 - acc: 0.9124 - val_loss: 1.1369 - val_acc: 0.6498
# Epoch 18/30
# 1735/1735 [==============================] - 59s 34ms/sample - loss: 0.2158 - acc: 0.9303 - val_loss: 1.2665 - val_acc: 0.6313
# Epoch 19/30
# 1735/1735 [==============================] - 60s 34ms/sample - loss: 0.1971 - acc: 0.9274 - val_loss: 1.1248 - val_acc: 0.6590
# Epoch 20/30
# 1735/1735 [==============================] - 60s 35ms/sample - loss: 0.1268 - acc: 0.9620 - val_loss: 1.2734 - val_acc: 0.6498
# Epoch 21/30
# 1735/1735 [==============================] - 62s 36ms/sample - loss: 0.1473 - acc: 0.9562 - val_loss: 1.4352 - val_acc: 0.6636
# Epoch 22/30
# 1735/1735 [==============================] - 63s 37ms/sample - loss: 0.1180 - acc: 0.9648 - val_loss: 1.3198 - val_acc: 0.6659
# Epoch 23/30
# 1735/1735 [==============================] - 73s 42ms/sample - loss: 0.0849 - acc: 0.9764 - val_loss: 1.3297 - val_acc: 0.6659
# Epoch 24/30
# 1735/1735 [==============================] - 71s 41ms/sample - loss: 0.0827 - acc: 0.9758 - val_loss: 1.5361 - val_acc: 0.6498
# Epoch 25/30
# 1735/1735 [==============================] - 79s 46ms/sample - loss: 0.1286 - acc: 0.9573 - val_loss: 1.6875 - val_acc: 0.6359
# Epoch 26/30
# 1735/1735 [==============================] - 91s 52ms/sample - loss: 0.1033 - acc: 0.9671 - val_loss: 1.4260 - val_acc: 0.6406
# Epoch 27/30
# 1735/1735 [==============================] - 94s 54ms/sample - loss: 0.0533 - acc: 0.9867 - val_loss: 1.5447 - val_acc: 0.6498
# Epoch 28/30
# 1735/1735 [==============================] - 103s 59ms/sample - loss: 0.0498 - acc: 0.9844 - val_loss: 1.5294 - val_acc: 0.6567
# Epoch 29/30
# 1735/1735 [==============================] - 86s 50ms/sample - loss: 0.0374 - acc: 0.9896 - val_loss: 1.4757 - val_acc: 0.6498
# Epoch 30/30
# 1735/1735 [==============================] - 82s 47ms/sample - loss: 0.0273 - acc: 0.9931 - val_loss: 1.5424 - val_acc: 0.6682
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_60 (Conv2D)           (None, 98, 98, 64)        1792
# _________________________________________________________________
# activation_98 (Activation)   (None, 98, 98, 64)        0
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 47, 47, 64)        36928
# _________________________________________________________________
# activation_99 (Activation)   (None, 47, 47, 64)        0
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# activation_100 (Activation)  (None, 21, 21, 64)        0
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dense_38 (Dense)             (None, 5)                 32005
# _________________________________________________________________
# activation_101 (Activation)  (None, 5)                 0
# =================================================================
# Total params: 107,653
# Trainable params: 107,653
# Non-trainable params: 0
# _________________________________________________________________
